# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dataset_path = '/content/drive/MyDrive/BBM416 - Computer Vision Project/OBJECT_RECOG/YOLO/yolo_dataset'

# %%
print(os.listdir(dataset_path))
# Out:
# ['yolo_config.yaml', 'yolo_config_alt.yaml', 'labels', 'images']

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.6/599.6 kB 10.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# Loading the model

# %%
model = YOLO("yolov8n.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# Using the model

# %%
results = model.train(data=os.path.join(dataset_path, 'yolo_config.yaml'), epochs=50)
# Out:
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/BBM416 - Computer Vision Project/yolo_results/final_results/50_epochs'
